# %%
from cluster import *
import pandas as pd
from sklearn.cluster import KMeans, MiniBatchKMeans

# %%
fileName = "/Users/kexinrong/Documents/dev/smartgrid/smartgrid-data/data/load/2012baseline_02.txt"

# %%
with open(fileName, 'r') as dataFile:
  firstLine = dataFile.readline()
  vectorLength = int(firstLine)

K = 50
all = np.loadtxt(fileName, skiprows=1)

timeNames = map(str, range(vectorLength))
columnNames = ['id', 'hvac', 'pv', 'ev', 'pool'] + map(str, range(vectorLength))

df = pd.DataFrame(all, columns=columnNames)

# %%
# K Means
data = df.get(timeNames)
km = KMeans(n_clusters=K, init='k-means++', max_iter=100, n_init=1)
km.fit(data)
df['label'] = km.labels_
centroids = pd.DataFrame(km.cluster_centers_)
df.head()
# Out:
#     id  hvac  pv  ev  pool         0         1         2         3         4  \
# 0  525     1   0   0     0  0.088189  0.082485  0.082485  0.082925  0.131869
# 1  526     1   0   0     0  0.522622  0.221497  0.194693  0.159143  0.136643
# 2  527     1   0   0     0  0.128884  0.086529  0.084085  0.084085  0.084878
# 3  528     0   0   0     0  0.325383  0.176605  0.143463  0.087510  0.083760
# 4  529     0   0   0     0  0.193034  0.173808  0.138595  0.119845  0.119933
#
#      ...           15        16        17        18        19        20  \
# 0    ...     0.207179  0.376293  0.510326  0.544572  0.626801  0.643634
# 1    ...     0.202921  0.214077  0.231970  0.449387  0.749148  0.828508
# 2    ...     0.141512  0.270757  0.444976  0.537146  0.551219  0.550828
# 3    ...     0.129231  0.150798  0.201054  0.357146  0.539355  0.628446
# 4    ...     0.507687  0.521461  0.586341  0.676305  0.730724  0.707708
#
#          21        22        23  label
# 0  0.366433  0.322796  0.289379      3
# 1  0.827088  0.842138  0.581519     32
# 2  0.430063  0.356722  0.313633      3
# 3  0.618685  0.553782  0.420292     26
# 4  0.450551  0.285904  0.235611     11
#
# [5 rows x 30 columns]

# %%
def get_size(df, label):
    return len(df[df['label'] == label])

# Calculate size for each centroid
maxLabel = len(centroids)
sizes = []
for i in range(maxLabel):
    sizes.append(get_size(df, i))
centroids['label'] = range(maxLabel)
centroids['size'] = sizes

# %%
centroids.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.151042  0.122265  0.107172  0.087527  0.079638  0.108850  0.178305
# 1  0.970808  0.565033  0.323394  0.202355  0.213918  0.527208  0.940201
# 2  0.450369  0.381865  0.352792  0.343212  0.329017  0.379784  0.542422
# 3  0.828983  0.594284  0.423890  0.352976  0.324863  0.281100  0.253931
# 4  1.247608  0.946591  0.719013  0.691600  0.808178  0.836432  0.678899
#
#           7         8         9    ...           16        17        18  \
# 0  0.251226  0.295594  0.311681    ...     0.353610  0.423721  0.521125
# 1  1.101156  0.750221  0.459818    ...     0.575734  0.537769  0.678259
# 2  0.708282  0.761712  0.778782    ...     0.933921  1.178718  1.400452
# 3  0.293169  0.449854  0.645822    ...     0.640424  0.697175  0.789329
# 4  0.708013  0.946810  1.294468    ...     1.478231  1.546052  1.759394
#
#          19        20        21        22        23  label  size
# 0  0.531208  0.440029  0.349882  0.260191  0.193819      0   436
# 1  0.993876  1.336184  1.427062  1.059705  0.632181      1    73
# 2  1.526115  1.359990  1.071702  0.824549  0.627167      2   277
# 3  0.902488  1.095293  1.247055  1.289330  1.084074      3   225
# 4  1.931425  1.944875  1.907640  1.831902  1.538034      4    77
#
# [5 rows x 26 columns]

# %%
def closestLabels(centroids):
    closestLabels = None
    shortestDistance = None
    for i in range(len(centroids)):
        c_i = np.array(centroids.iloc[i : i + 1, : -2])
        for j in range(len(centroids)):
            if i == j:
                continue
            c_j = np.array(centroids.iloc[j : j + 1, : -2])
            d_ij = LA.norm(c_i - c_j)
            if shortestDistance == None or d_ij < shortestDistance:
                shortestDistance = d_ij
                l_i = int(centroids.iloc[i : i+1, : ]['label'].values[0])
                l_j = int(centroids.iloc[j : j+1, : ]['label'].values[0])
                closestLabels = (l_i, l_j)
    return closestLabels

# %%
N = 30
while len(centroids) > N:
    (l_i, l_j) = closestLabels(centroids)
    c_i = np.array(centroids[centroids['label'] == l_i].iloc[:, :-2])
    c_j = np.array(centroids[centroids['label'] == l_j].iloc[:, :-2])
    n_i = centroids[centroids['label'] == l_i]['size'].values[0]
    n_j = centroids[centroids['label'] == l_j]['size'].values[0]
    new_c = (n_i * c_i + n_j * c_j) / (n_i + n_j)
    for i in range(len(centroids)):
        label = centroids.iloc[i : i+1, :]['label'].values[0]
        if label == l_i:
            centroids.iloc[i : i+1, : -2] = new_c
            centroids.iloc[i : i+1, : ]['size'] = n_i + n_j
    # Delete one centroid
    centroids = centroids.drop(l_j)
    # Change all l2 label in df to l1
    count = len(df[df['label'] == l_j])
    df.loc[df['label'] == l_j] = l_i

# %%
centroids
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.467319  0.366844  0.318721  0.281680  0.277999  0.297312  0.358570
# 1   0.250410  0.181332  0.144344  0.116903  0.108735  0.122929  0.175914
# 2   0.409661  0.335839  0.278266  0.256783  0.238365  0.242473  0.281201
# 3   0.922965  0.899737  1.516125  1.508963  0.565679  0.443982  0.836931
# 6   0.629348  0.474631  0.619174  1.000338  1.207684  0.825136  0.523902
# 7   1.083596  0.760979  0.617677  0.581712  0.580775  0.607359  0.552726
# 10  0.483085  0.315878  0.306323  0.595794  1.032808  1.125192  0.644867
# 12  0.907774  0.817181  0.620421  0.977404  0.818578  0.685577  0.730154
# 13  0.368299  0.163314  0.141375  0.104227  0.104227  0.104981  0.234020
# 15  0.417015  0.348885  0.397220  0.410095  0.279871  0.260817  0.379632
# 16  0.457078  0.783934  1.091099  0.962056  0.440254  0.226088  0.247429
# 17  0.570381  0.511496  0.526282  0.534984  0.542168  0.614934  0.750347
# 18  2.321441  3.476387  3.451397  3.179879  2.354879  0.784126  0.174668
